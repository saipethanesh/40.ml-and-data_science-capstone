# %%
import pandas as pd

# %%
dataset=pd.read_csv("Automobilecodedata.csv")

# %%
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0        4.0         140.0        86.0  2790.0          15.6
# 394  44.0        4.0          97.0        52.0  2130.0          24.6
# 395  32.0        4.0         135.0        84.0  2295.0          11.6
# 396  28.0        4.0         120.0        79.0  2625.0          18.6
# 397  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model_year                       name  origin
# 0          70.0  chevrolet chevelle malibu     usa
# ...

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0        8.0         307.0       130.0  3504.0          12.0
# 1    15.0        8.0         350.0       165.0  3693.0          11.5
# 2    18.0        8.0         318.0       150.0  3436.0          11.0
# 3    16.0        8.0         304.0       150.0  3433.0          12.0
# 4    17.0        8.0         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0        4.0         140.0        86.0  2790.0          15.6
# 394  44.0        4.0          97.0        52.0  2130.0          24.6
# 395  32.0        4.0         135.0        84.0  2295.0          11.6
# 396  28.0        4.0         120.0        79.0  2625.0          18.6
# 397  31.0        4.0         119.0        82.0  2720.0          19.4
#
#      model_year  name_amc ambassador dpl  name_amc ambassador sst  \
# 0          70.0                        0                        0
# ...

# %%
dataset.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'name_amc ambassador dpl',
#        'name_amc ambassador sst', 'name_amc concord',
#        ...
#        'name_volvo 245', 'name_volvo 264gl', 'name_volvo diesel',
#        'name_vw dasher (diesel)', 'name_vw pickup', 'name_vw rabbit',
#        'name_vw rabbit c (diesel)', 'name_vw rabbit custom', 'origin_japan',
#        'origin_usa'],
#       dtype='object', length=313)

# %%
independent=dataset[['mpg', 'cylinders', 'displacement', 'horsepower', 'acceleration']]

# %%
independent
# Out:
#       mpg  cylinders  displacement  horsepower  acceleration
# 0    18.0        8.0         307.0       130.0          12.0
# 1    15.0        8.0         350.0       165.0          11.5
# 2    18.0        8.0         318.0       150.0          11.0
# 3    16.0        8.0         304.0       150.0          12.0
# 4    17.0        8.0         302.0       140.0          10.5
# ..    ...        ...           ...         ...           ...
# 393  27.0        4.0         140.0        86.0          15.6
# 394  44.0        4.0          97.0        52.0          24.6
# 395  32.0        4.0         135.0        84.0          11.6
# 396  28.0        4.0         120.0        79.0          18.6
# 397  31.0        4.0         119.0        82.0          19.4
#
# [398 rows x 5 columns]

# %%
dependent=dataset[['mpg']]

# %%
dependent
# Out:
#       mpg
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# ..    ...
# 393  27.0
# 394  44.0
# 395  32.0
# 396  28.0
# 397  31.0
#
# [398 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split( independent, dependent, test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train) #
# Out:
# LinearRegression()

# %%
weight=regressor.coef_
weight
# Out:
# array([[ 1.00000000e+00, -5.38776680e-17,  2.89462383e-17,
#         -1.35568283e-16,  1.32210630e-17]])

# %%
bais=regressor.intercept_
bais
# Out:
# array([3.55271368e-15])

# %%
y_pred=regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score 
r_score=r2_score(y_test,y_pred)

# %%
r_score
# Out:
# 1.0

# %%
import pickle
filename="finalized_model_Automobilecodedata.sav"
pickle.dump(regressor,open(filename,'wb'))

# %%
loaded_model=pickle.load(open("finalized_model_Automobilecodedata.sav", 'rb'))
result=loaded_model.predict([[567,789,91011,12,13]])
# Out:
# C:\anaconda3\envs\AIML\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
result
# Out:
# array([[567.]])
