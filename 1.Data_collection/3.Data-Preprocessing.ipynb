# %%
import pandas as pd

# %%
dataset=pd.read_csv("study_performance.csv")

# %%
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
dataset.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
#1)Replace the missing value with central tendency-Mean Median Mode
#2)Entire Row delete
#3)REspective to the problem ,have to replace the missing values
#4)Consider this as a semi supervised, create a model, so that we can predict the missing values.

# %%
dataset.isna().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
dataset["test_preparation_course"].fillna(0,inplace=True)

# %%
dataset.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# dtype: int64

# %%
dataset.dropna(inplace=True)

# %%
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
dataset["test_preparation_course"].fillna(dataset["test_preparation_course"].mean(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1602         try:
# -> 1603             x = float(x)
#    1604         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\anaconda3\envs\AIML\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1606             try:
# -> 1607                 x = complex(x)
#    1608             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ...

# %%
dataset
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qaul=quanQual(dataset)

# %%
dataset[quan]
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])
df = pd.DataFrame(df,columns = quan)

# %%
df
# Out:
#      math_score  reading_score  writing_score
# 0          72.0           72.0           74.0
# 1          69.0           90.0           88.0
# 2          90.0           95.0           93.0
# 3          47.0           57.0           44.0
# 4          76.0           78.0           75.0
# ..          ...            ...            ...
# 995        88.0           99.0           95.0
# 996        62.0           55.0           55.0
# 997        59.0           71.0           65.0
# 998        68.0           78.0           77.0
# 999        77.0           86.0           86.0
#
# [1000 rows x 3 columns]

# %%
cate=dataset[qaul]

# %%
df
# Out:
#      math_score  reading_score  writing_score
# 0          72.0           72.0           74.0
# 1          69.0           90.0           88.0
# 2          90.0           95.0           93.0
# 3          47.0           57.0           44.0
# 4          76.0           78.0           75.0
# ..          ...            ...            ...
# 995        88.0           99.0           95.0
# 996        62.0           55.0           55.0
# 997        59.0           71.0           65.0
# 998        68.0           78.0           77.0
# 999        77.0           86.0           86.0
#
# [1000 rows x 3 columns]

# %%
cate
# Out:
#      gender race_ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two,axis=1)

# %%
preprocessed
# Out:
#      math_score  reading_score  writing_score  gender race_ethnicity  \
# 0          72.0           72.0           74.0  female        group B
# 1          69.0           90.0           88.0  female        group C
# 2          90.0           95.0           93.0  female        group B
# 3          47.0           57.0           44.0    male        group A
# 4          76.0           78.0           75.0    male        group C
# ..          ...            ...            ...     ...            ...
# 995        88.0           99.0           95.0  female        group E
# 996        62.0           55.0           55.0    male        group C
# 997        59.0           71.0           65.0  female        group C
# 998        68.0           78.0           77.0  female        group D
# 999        77.0           86.0           86.0  female        group D
#
#     parental_level_of_education         lunch test_preparation_course
# ...

# %%
preprocessed.isnull().sum()
# Out:
# math_score                     0
# reading_score                  0
# writing_score                  0
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# dtype: int64

# %%
preprocessed.to_csv("study_performancedata.csv",index=False)
